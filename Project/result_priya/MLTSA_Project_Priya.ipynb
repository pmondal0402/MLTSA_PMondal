# %%
# Author : P. Mondal
# Date : March 22, 2020
# Date : March 26, 2020

# %%
# Packages :
import pandas as pd
import pylab as pl
import json
import os
# %pylab inline

pl.style.use("bmh")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from google.colab import drive

drive.mount("/content/gdrive")

# %pwd
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive
# '/content'

# %%
# Download stock data
# %cd gdrive/My\ Drive
# Out:
# /content/gdrive/My Drive

# %%
# %ls kaggle.json
# !chmod 600 kaggle.json

import json
import os

envs = json.load(open("kaggle.json", "r"))
os.environ["KAGGLE_USERNAME"] = envs['username']
os.environ["KAGGLE_KEY"] = envs['key']

# !kaggle datasets list -s stock
# Out:
# kaggle.json
# ...
# ref                                                       title                                                size  lastUpdated          downloadCount
# --------------------------------------------------------  --------------------------------------------------  -----  -------------------  -------------
# borismarjanovic/price-volume-data-for-all-us-stocks-etfs  Huge Stock Market Dataset                           492MB  2017-11-16 14:53:29          51371
# dgawlik/nyse                                              New York Stock Exchange                              31MB  2017-02-22 10:18:25          38671
# camnugent/sandp500                                        S&P 500 stock data                                   19MB  2018-02-10 03:15:53          25420
# aaron7sun/stocknews                                       Daily News for Stock Market Prediction                6MB  2019-11-13 18:22:52          28949
# ...

# %%
# %pwd
# Out:
# '/content/gdrive/My Drive'

# %%
'''
# %cd gdrive/My\ Drive/
# %cd MLTSA\ Project
# !pwd
'''
# Out:
# '\n# %cd gdrive/My\\ Drive/\n%cd MLTSA\\ Project\n!pwd\n'

# %%
'''
# %cd gdrive/My\ Drive/
# %cd MLTSA\ Project
# %cd data\ for\ stocks
'''
# Out:
# '\n%cd gdrive/My\\ Drive/\n%cd MLTSA\\ Project\n%cd data\\ for\\ stocks\n'

# %%
# !ls

# %%
'''
# Testing stock data for APPLE
data_apl = pd.read_csv('AAPL.csv')
data_apl.head()
#data_apl.tail()
'''
# Out:
# "\n# Testing stock data for APPLE\ndata_apl = pd.read_csv('AAPL.csv')\ndata_apl.head()\n#data_apl.tail()\n"

# %%
# Convert to datetime object
# data_apl["Date"]
#data_apl["Low"]
#data_apl_test = data_apl.dropna(subset=["Low"])
#data_apl["time"] = pd.to_datetime[data_apl["Date"]]
#type(data_apl)
#data_apl.describe
#data_apl['time'] = pd.to_datetime[data_apl["Close/Last"]]

# %%
# data_apl.iloc[0]

# %%
'''
xx = np.array(data_apl.index)
#data_apl["Volume"]
yy = data_apl.columns.to_list
data_apl.columns
'''
# Out:
# '\nxx = np.array(data_apl.index)\n#data_apl["Volume"]\nyy = data_apl.columns.to_list\ndata_apl.columns\n'

# %%
#data_apl.iloc[1]
#data_apl["Low"]

# %% [markdown]
# # Testing another set

# %%
'''
# %cd ../../
# %pwd
'''
# Out:
# '\n%cd ../../\n%pwd\n'

# %%
# %cd MLTSA\ Project/

# %%
'''
# %cd Data/ic_frm_femm_zs_zip/
# %cd data/
'''
# %ls
# Out:
# '\n%cd Data/ic_frm_femm_zs_zip/\n%cd data/\n'

# %%
# data_test2 = pd.read_csv('data_csv.csv')

# %%
# data_test2.head()

# %%
# data_test2["Year"]

# %%
# data_test2["Value"]

# %%
# NEED TO SORT DATE BASED ON YEAR ????
# APPLE DATA : CAN'T READ OTHER THAN 1st COLUMN
# 
# data_test2.plot( y = 'Value', figsize=(28,10), color='blue')

# %% [markdown]
# # Test3

# %%
# %pwd
# %cd ../Data
#%cd

# %%
# %ls

# %%
'''
# Test data 3
data_test3 = pd.read_csv('ONLYS&P500TIMESERIES.csv')
data_test3.head()
'''
# Out:
# "\n# Test data 3\ndata_test3 = pd.read_csv('ONLYS&P500TIMESERIES.csv')\ndata_test3.head()\n"

# %%
# data_test3["date"]

# %%
# data_test3["COMNAM"]

# %%
# data_test3.describe()

# %%
# data_test3.plot(y='PRC',  figsize=(28,10), color='blue')

# %% [markdown]
# # Female CEO

# %%
# %cd MLTSA\ Project
# %cd Results/Priya
# %mkdir data_fe_CEO_Stock
# %cd data_fe_CEO_Stock
# %pwd
# Out:
# /content/gdrive/My Drive/MLTSA Project
# /content/gdrive/My Drive/MLTSA Project/Results/Priya
# mkdir: cannot create directory ‘data_fe_CEO_Stock’: File exists
# /content/gdrive/My Drive/MLTSA Project/Results/Priya/data_fe_CEO_Stock
# '/content/gdrive/My Drive/MLTSA Project/Results/Priya/data_fe_CEO_Stock'

# %%
# !kaggle datasets download borismarjanovic/price-volume-data-for-all-us-stocks-etfs
# Out:
# price-volume-data-for-all-us-stocks-etfs.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# %ls
# Out:
# Data/  ETFs/  price-volume-data-for-all-us-stocks-etfs.zip  Stocks/

# %%
 # !unzip price-volume-data-for-all-us-stocks-etfs.zip
# Out:
# Archive:  price-volume-data-for-all-us-stocks-etfs.zip
# replace Data/ETFs/aadr.us.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace Data/ETFs/aaxj.us.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: n
# replace Data/ETFs/acim.us.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# %cd ../../
# %pwd
# Out:
# /content/gdrive/My Drive/MLTSA Project/Results
# '/content/gdrive/My Drive/MLTSA Project/Results'

# %%
# Read data
# %cd 
# %cd Priya/data
# Out:
# /content/gdrive/My Drive/MLTSA Project/Results/Priya/data

# %%
# %pwd
# %ls
# Out:
# FemaleCEOTimeline.xlsx

# %%
data = pd.read_excel('FemaleCEOTimeline.xlsx')

# %%
data.head()
# Out:
#       Company   Company.1  ... Previous CEO 2  Previous CEO 2 Date Employed
# 0          GM          GM  ...              2           2009-12-01 00:00:00
# 1    Best Buy    Best Buy  ...              2           2020-06-09 00:00:00
# 2  Anthem Inc  Anthem Inc  ...              1                 june 1st 2007
# 3  Mylan N.V.  Mylan N.V.  ...            NaN                           NaN
# 4     Hershey     Hershey  ...              2                          2007
#
# [5 rows x 9 columns]

# %%
# data.tail()
data.columns
# Out:
# Index(['Company', 'Company.1', 'Current CEO', 'Gender (1 female, 2 male)',
#        'Date Employed', 'Previous CEO Gender', 'Previous CEO Date Employed',
#        'Previous CEO 2', 'Previous CEO 2 Date Employed'],
#       dtype='object')

# %%
# Are any of previous CEO female ??
# If yes, how many ?
prev_CEO = np.array(data["Previous CEO Gender"])
# print(prev_CEO)
type(prev_CEO[0])
for ii in range(len(prev_CEO)):
  if (prev_CEO[ii] == 1):
    print('previous Female CEO', ii)

# Ans : 1 female CEO previously
# Out:
# previous Female CEO 59

# %%
# Are any of current CEO female ??
# If yes, how many ?

curr_CEO = np.array(data["Gender (1 female, 2 male)"])
count = 0
ind_fe = np.empty(len(curr_CEO))
for ii in range(len(curr_CEO)):
  if (curr_CEO[ii] == 1):
    ind_fe[ii] = ii
    count = count +1
    #print('Current Female CEO', ii)

print('Total number of current female CEO', count)

# Ans : 1 female CEO previously
print('Total number of companies', len(curr_CEO))
# Out:
# Total number of current female CEO 33
# Total number of companies 65

# %%
# Find name of the companies with current female CEO

# Name of companies with female CEO
cmpny_name = list(data["Company"])
cmpny_fe = np.empty(count)

for ii in range(count):
  print(cmpny_name[ii])
  # Read all stock.csv for these stocks
# Out:
# GM
# Best Buy
# Anthem Inc
# Mylan N.V.
# Hershey
# Ventas
# Oracle
# Ulta
# Nasdaq
# Kohls
# Duke
# Progressive
# Lockheed Martin
# Occidenal
# Franklin Resources
# Synchrony
# CDW
# KeyBank
# General Dynamics
# Regency Centers
# Zoetis
# CMS
# Ross
# IBM
# Celanese
# American Water Works
# Advanced
# Accenture
# Arista
# Northrop
# Gap
# Vertex
# UPS

# %%
# data['Company']

# %%
# Create list with stock symbols
data_fe_sym = ['gm', 'bby', 'antm', 'myl', 'hsy', 'vtr', 'orcl', 'ulta', 'ndaq', 'kss', 'duk', 'pgr', 'lmt', 'oxy', 'ben', 'syf', 'cdw', 'key', 'gd', 'reg', 'zts', 'cms', 'rost', 'ibm', 'ce', 'awk', 'amd', 'acn', 'anet', 'noc', 'gps', 'vrtx', 'ups']

for ii in range(len(data_fe_sym)):
  strr = '../data_fe_CEO_Stock/Data/Stocks/' + data_fe_sym[ii] + '.us.txt'
  #print(strr)
  data = pd.read_csv('../data_fe_CEO_Stock/Data/Stocks/' + data_fe_sym[ii] + '.us.txt')

#for item in data_fe_sym:
#  print(item)

# %%
#data.head()
list_of_dfs = [pd.read_csv('../data_fe_CEO_Stock/Data/Stocks/' + str(item) + '.us.txt') for item in data_fe_sym]

for dataframe, item in zip(list_of_dfs, data_fe_sym):
  dataframe['item'] = item

# %%
for ii in range(len(data_fe_sym)):
  figure()
  ax = list_of_dfs[ii].plot(x='Date', y='Close', label=str(data_fe_sym[ii]), figsize=(22,8), color='blue', title="Stock performance (Current female CEO)")
  ax.set_xlabel('')
  ax.set_ylabel('Closing Stock Price ($)')

  SMALL_SIZE = 18
  MEDIUM_SIZE = 10
  BIGGER_SIZE = 12

  pl.rc('font', size=SMALL_SIZE)          # controls default text sizes

  pl.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
  pl.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
  pl.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
  pl.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
  axis_font = {'fontname':'Computer Modern Roman', 'size':'18'}
  pl.xlabel("Date (yyyy/mm/dd)", **axis_font)
  pl.ylabel("Closing Stock Price ($)", **axis_font)
  pl.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
  pl.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
  plt.tight_layout()
  pl.savefig('../result_priya/stockfigs_TM_series/ ' + str(data_fe_sym[ii])+ '.png')
# You can see if it worked by looking at list_of_dfs[0] and list_of_dfs[-1] to 
# see if the first and last both have the filename in there.
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
# %pwd
# Out:
# '/content/gdrive/My Drive/MLTSA Project/Results/Priya/data'

# %%
# You can see if it worked by looking at list_of_dfs[0] and list_of_dfs[-1] to 
# see if the first and last both have the filename in there.
list_of_dfs[-1]
# Out:
#             Date     Open     High      Low    Close    Volume  OpenInt item
# 0     1999-11-10   51.042   55.211   50.649   53.590  98281166        0  ups
# 1     1999-11-11   53.985   60.412   53.985   58.893  34436368        0  ups
# 2     1999-11-12   59.683   60.168   54.379   55.361  17964593        0  ups
# 3     1999-11-15   55.361   55.655   52.859   54.182  10552792        0  ups
# 4     1999-11-17   51.485   53.542   51.141   53.158   7063781        0  ups
# ...          ...      ...      ...      ...      ...       ...      ...  ...
# 4522  2017-11-06  114.730  115.140  112.760  113.080   3365935        0  ups
# 4523  2017-11-07  112.990  114.010  112.790  113.110   2750214        0  ups
# 4524  2017-11-08  112.820  112.860  111.820  112.300   2389472        0  ups
# 4525  2017-11-09  112.000  112.170  110.900  111.720   2733805        0  ups
# 4526  2017-11-10  111.570  113.270  111.304  113.230   2839998        0  ups
#
# [4527 rows x 8 columns]

# %%
# Combine a list of dataframes, on top of each other
combined_df = pd.concat(list_of_dfs, ignore_index=True)
print(combined_df.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt', 'item'], dtype='object')

# %%
# Is there is correlation betwwen performances of these stocks ??
# Check HW1 (repeat similar stuff)

# This is wrong 
'''
# Visualizing correlation between these stocks
from pandas.plotting import scatter_matrix
scatter_matrix(combined_df, color = "#222222", figsize=(20,20))
'''
# %ls ../data_fe_CEO_Stock/Data/Stocks/
pd.merge?
# Out:
# aaap.us.txt       dhr.us.txt        jmlp.us.txt       quad.us.txt
# aaba.us.txt       dht.us.txt        jmm.us.txt        quik.us.txt
# aac.us.txt        dhvw.us.txt       jmom.us.txt       qumu.us.txt
# aal.us.txt        dhxm.us.txt       jmpb.us.txt       quot.us.txt
# aamc.us.txt       dhx.us.txt        jmpc.us.txt       qure.us.txt
# aame.us.txt       dhy.us.txt        jmp.us.txt        q.us.txt
# aan.us.txt        dial.us.txt       jmt.us.txt        qval.us.txt
# aaoi.us.txt       diax.us.txt       jmu.us.txt        qvca.us.txt
# aaon.us.txt       din.us.txt        jnce.us.txt       qvcb.us.txt
# aapl.us.txt       diod.us.txt       jnj.us.txt        qvm.us.txt
# aap.us.txt        disca.us.txt      jnpr.us.txt       qxgg.us.txt
# aat.us.txt        discb.us.txt      jnp.us.txt        qxmi.us.txt
# aa.us.txt         disck.us.txt      jobs.us.txt       qxrr.us.txt
# aau.us.txt        dish.us.txt       job.us.txt        qxtr.us.txt
# ...

# %%
tss = pd.read_csv('../data_fe_CEO_Stock/Data/Stocks/' + data_fe_sym[0] + '.us.txt')[["Date", 
	
                                "Close"]].rename({
	
      "Close": ('../data_fe_CEO_Stock/Data/Stocks/' + data_fe_sym[0] + 
      '.us.txt').replace(".txt","")}, axis=1)
data_cutoff = 29
for f in data_fe_sym[data_cutoff:]:
    # print(f)
    fileread = '../data_fe_CEO_Stock/Data/Stocks/' + str(f) + '.us.txt'
    name = fileread.replace(".txt", "")

    tss = tss.merge(pd.read_csv(fileread)[["Date", "Close"]].rename(
	
      {"Close":name}, axis=1), on="Date")
    
tss.set_index("Date", inplace=True)

print ("shape of the dataset:", tss.shape)
print(tss.columns)
tss
# Out:
# shape of the dataset: (1756, 5)
# Index(['../data_fe_CEO_Stock/Data/Stocks/gm.us',
#        '../data_fe_CEO_Stock/Data/Stocks/noc.us',
#        '../data_fe_CEO_Stock/Data/Stocks/gps.us',
#        '../data_fe_CEO_Stock/Data/Stocks/vrtx.us',
#        '../data_fe_CEO_Stock/Data/Stocks/ups.us'],
#       dtype='object')
#             ../data_fe_CEO_Stock/Data/Stocks/gm.us  ...  ../data_fe_CEO_Stock/Data/Stocks/ups.us
# Date                                                ...
# 2010-11-17                                  28.258  ...                                   55.275
# 2010-11-18                                  29.276  ...                                   56.041
# 2010-11-19                                  29.339  ...                                   56.811
# 2010-11-22                                  29.182  ...                                   56.549
# 2010-11-23                                  28.468  ...                                   56.033
# ...

# %%
#tss.rename(columns={"../data_fe_CEO_Stock/Data/Stocks/gm.us": "a"})
#tss
'''
tss.rename(columns={"../data_fe_CEO_Stock/Data/Stocks/gm.us":"tesssst"})
#tss.rename(columns={("../data_fe_CEO_Stock/Data/Stocks/" + str(data_fe_sym[0]) + ".us"):str(data_fe_sym[0])+".us"})
tss["tesssst"]
'''
# Out:
# '\ntss.rename(columns={"../data_fe_CEO_Stock/Data/Stocks/gm.us":"tesssst"})\n#tss.rename(columns={("../data_fe_CEO_Stock/Data/Stocks/" + str(data_fe_sym[0]) + ".us"):str(data_fe_sym[0])+".us"})\ntss["tesssst"]\n'

# %%
# tss.rename(columns={"../data_fe_CEO_Stock/Data/Stocks/gps.us":"gps.us"})
tss.columns = [item for item in data_fe_sym[data_cutoff-1:]]
print(tss.shape)
#Testing tss
'''
for c in tss.columns:
      print(c)
      fig, ax = pl.subplots(figsize=(10,4))
      tss.plot(y=c, ax=ax, rot=75)
'''
# Out:
# (1756, 5)
# '\nfor c in tss.columns:\n      print(c)\n      fig, ax = pl.subplots(figsize=(10,4))\n      tss.plot(y=c, ax=ax, rot=75)\n'

# %%
# %pwd
# %ls ../result_priya/Correlation/

# %%
# Visualize correlation
  from pandas.plotting import scatter_matrix
# ax, fig = pl.subplots(1, figsize=(10,10))
  fig = figure(1)
  ax = scatter_matrix(tss, color="black", figsize=(20,20))
  ax[0,2].set_title('Correlation Between Different Stocks With Female CEO')
  #pl.suptitle('scattx')
  #x, y ticklabels
  [pl.setp(item.xaxis.get_majorticklabels(), 'size', 20) for item in ax.ravel()]
  [pl.setp(item.yaxis.get_majorticklabels(), 'size', 20) for item in ax.ravel()]
  
  #x, y labels
  [pl.setp(item.xaxis.get_label(), 'size', 20) for item in ax.ravel()]
  [pl.setp(item.yaxis.get_label(), 'size', 20) for item in ax.ravel()]
  pl.tight_layout()
  pl.savefig('../result_priya/Correlation/ ' + 'correlation_last5stock'+ '.png')
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:307: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /usr/local/lib/python3.6/dist-packages/pandas/plotting/_matplotlib/tools.py:313: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
# Get correlation
tss.corr()
# Out:
#           anet       noc       gps      vrtx       ups
# anet  1.000000  0.735165  0.306778  0.692886  0.777737
# noc   0.735165  1.000000  0.049614  0.799301  0.936688
# gps   0.306778  0.049614  1.000000  0.385277  0.310822
# vrtx  0.692886  0.799301  0.385277  1.000000  0.820124
# ups   0.777737  0.936688  0.310822  0.820124  1.000000

# %%
  # Plot correlation
  from mpl_toolkits.axes_grid1.inset_locator import inset_axes

  pl.figure(figsize=(20,10))
  fig, ax = pl.subplots(1,1,  constrained_layout=True, figsize=(20,10)) 

  im = pl.imshow(tss.corr())
  pl.xticks(range(len(tss.columns)), tss.columns, rotation=90)
  pl.yticks(range(len(tss.columns)), tss.columns)
  ax.set_title('Autocorrelation')
  cbaxes = fig.add_axes([0.75, 0.1, 0.03, 0.8]) 

  fig.colorbar(im , orientation="vertical", cax = cbaxes )

  SMALL_SIZE = 18
  MEDIUM_SIZE = 10
  BIGGER_SIZE = 12

  pl.rc('font', size=SMALL_SIZE)          # controls default text sizes
  # pl.title("Correlation")  
  pl.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
  pl.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
  pl.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
  pl.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
  print(ax)
  axis_font = {'fontname':'Computer Modern Roman', 'size':'18'}
  # pl.xlabel("Date (yyyy/mm/dd)", **axis_font)
  # pl.ylabel("Closing Stock Price ($)", **axis_font)
  pl.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
  pl.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

  

  pl.tight_layout()
  pl.savefig('../result_priya/Correlation/ ' + 'correlation_fig2'+ '.png')
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:33: UserWarning: This figure was using constrained_layout==True, but that is incompatible with subplots_adjust and or tight_layout: setting constrained_layout==False.

# %%
# TODO
# %ls ../data_fe_CEO_Stock/
# %ls ../result_priya/Correlation/
# Out:
# Data/  ETFs/  price-volume-data-for-all-us-stocks-etfs.zip  Stocks/
# ' correlation_fig2.png'  ' correlation_last5stock.png'

# %%
# Get stock performance for the above stocks
# %pwd
# Out:
# '/content/gdrive/My Drive/MLTSA Project/Results/Priya/data'

# %%
# Find cumulative return of those company stocks in past 120 days preceding and
# 100 days following the appointment of female CEOs
# a> Find timeline of female CEO
# b> Find 120 days preceding and
#    100 days following the appointment of female CEOs
# c> Plot fig similar to fig 1 in leeth et al.
# Event detectuon for some of these stocks
# Can we detect 2008 recession ??
# How much was the stock prce affected by COVID-19 ??
